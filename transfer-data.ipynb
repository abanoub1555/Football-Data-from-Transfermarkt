# %%
import pandas as pd
apperance_table = pd.read_csv("data/appearances.csv")
apperance_table.head(100)
# Out:
#      appearance_id  game_id  player_id  player_club_id  \
# 0    2231978_38004  2231978      38004             853
# 1    2233748_79232  2233748      79232            8841
# 2    2234413_42792  2234413      42792            6251
# 3    2234418_73333  2234418      73333            1274
# 4   2234421_122011  2234421     122011             195
# ..             ...      ...        ...             ...
# 95   2222962_58051  2222962      58051            2477
# 96   2222962_58150  2222962      58150            2477
# 97   2222962_58252  2222962      58252            4482
# 98   2222962_58425  2222962      58425            2477
# 99   2222962_58976  2222962      58976            4482
#
#     player_current_club_id        date          player_name competition_id  \
# 0                      235  2012-07-03     Aurélien Joachim            CLQ
# 1                     2698  2012-07-05       Ruslan Abyshov            ELQ
# 2                      465  2012-07-05          Sander Puri            ELQ
# ...

# %%
#reading 1st fact table (apperance)
apperance_table.drop(columns=["player_name"],inplace=True)
apperance_table.head()

# %%
#reading club dimension
club_dimension=pd.read_csv("data/clubs.csv")
club_dimension.head()
# Out:
#    club_id          club_code                             name  \
# 0      105    sv-darmstadt-98                  SV Darmstadt 98
# 1    11127  ural-ekaterinburg               Ural Yekaterinburg
# 2      114  besiktas-istanbul        Beşiktaş Jimnastik Kulübü
# 3       12             as-rom       Associazione Sportiva Roma
# 4      148  tottenham-hotspur  Tottenham Hotspur Football Club
#
#   domestic_competition_id  total_market_value  squad_size  average_age  \
# 0                      L1                 NaN          27         25.6
# 1                     RU1                 NaN          30         26.5
# 2                     TR1                 NaN          30         26.5
# 3                     IT1                 NaN          26         26.3
# 4                     GB1                 NaN          30         25.4
#
#    foreigners_number  foreigners_percentage  national_team_players  \
# 0                 13                   48.1                      1
# ...

# %%
#reading competitions_dimension
competitions_dimension=pd.read_csv("data/competitions.csv")
competitions_dimension.drop(columns=["country_id"],inplace=True)
competitions_dimension.head()
# Out:
#   competition_id               competition_code  \
# 0            CIT                      italy-cup
# 1           NLSC           johan-cruijff-schaal
# 2            GRP                kypello-elladas
# 3           POSU  supertaca-candido-de-oliveira
# 4           RUSS              russian-super-cup
#
#                             name            sub_type          type  \
# 0                      italy-cup        domestic_cup  domestic_cup
# 1           johan-cruijff-schaal  domestic_super_cup         other
# 2                kypello-elladas        domestic_cup  domestic_cup
# 3  supertaca-candido-de-oliveira  domestic_super_cup         other
# 4              russian-super-cup  domestic_super_cup         other
#
#   country_name domestic_league_code confederation  \
# 0        Italy                  IT1        europa
# 1  Netherlands                  NL1        europa
# 2       Greece                  GR1        europa
# 3     Portugal                  PO1        europa
# ...

# %%
#reading player_dimension
player_dimension=pd.read_csv("data/players.csv")
player_dimension.drop(columns=["current_club_domestic_competition_id"],inplace=True)
player_dimension.head()
# Out:
#    player_id first_name     last_name                name  last_season  \
# 0         10   Miroslav         Klose      Miroslav Klose         2015
# 1         26      Roman  Weidenfeller  Roman Weidenfeller         2017
# 2         65    Dimitar      Berbatov    Dimitar Berbatov         2015
# 3         77        NaN         Lúcio               Lúcio         2012
# 4         80        Tom        Starke          Tom Starke         2017
#
#    current_club_id         player_code    country_of_birth city_of_birth  \
# 0              398      miroslav-klose              Poland         Opole
# 1               16  roman-weidenfeller             Germany          Diez
# 2             1091    dimitar-berbatov            Bulgaria   Blagoevgrad
# 3              506               lucio              Brazil      Brasília
# 4               27          tom-starke  East Germany (GDR)       Freital
#
#   country_of_citizenship  ...    position   foot height_in_cm  \
# ...

# %%
#transform club_dimension
club_dimension = pd.merge(club_dimension, competitions_dimension[['competition_id', 'name']].rename(columns={'name': 'competition_name'}),left_on='domestic_competition_id', right_on='competition_id')
club_dimension.drop(columns=["domestic_competition_id","competition_id"],inplace=True)
club_dimension.head()
# Out:
#    club_id                 club_code  \
# 0      105           sv-darmstadt-98
# 1      269             holstein-kiel
# 2     4795          fc-ingolstadt-04
# 3        4             1-fc-nurnberg
# 4       18  borussia-monchengladbach
#
#                                                 name  total_market_value  \
# 0                                    SV Darmstadt 98                 NaN
# 1          Kieler Sportvereinigung Holstein von 1900                 NaN
# 2                                   FC Ingolstadt 04                 NaN
# 3                                     1.FC Nuremberg                 NaN
# 4  Borussia Verein für Leibesübungen 1900 Mönchen...                 NaN
#
#    squad_size  average_age  foreigners_number  foreigners_percentage  \
# 0          27         25.6                 13                   48.1
# 1          30         26.0                 12                   40.0
# 2          28         24.3                  8                   28.6
# ...

# %%
#transform player_dimension
player_dimension=pd.merge(player_dimension,club_dimension[["club_id","name"]].rename(columns={'name': 'club_name'}),left_on='current_club_id', right_on='club_id')
player_dimension.drop(columns=["current_club_id","club_id"])
# Out:
#        player_id first_name       last_name              name  last_season  \
# 0             10   Miroslav           Klose    Miroslav Klose         2015
# 1           4015      Louis            Saha        Louis Saha         2012
# 2           5812   Cristian         Brocchi  Cristian Brocchi         2012
# 3           6026    Tommaso          Rocchi    Tommaso Rocchi         2012
# 4           6043    Stefano           Mauri     Stefano Mauri         2015
# ...          ...        ...             ...               ...          ...
# 32596     789478     Bogdan          Kobzar     Bogdan Kobzar         2024
# 32597     825229    Valeriy           Samar     Valeriy Samar         2024
# 32598     925044      Taras           Galas       Taras Galas         2024
# 32599     926003     Maksym         Serdyuk    Maksym Serdyuk         2024
# 32600    1375876        NaN  Diego Henrique    Diego Henrique         2024
#
# ...
